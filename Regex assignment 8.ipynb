# %% [markdown]
# # TASK 8
#
# Registration ID : SIRSS2140
#
# RAJ SANKAR GS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
heart_data= pd.read_csv('/Volumes/RAJ SANKAR/Regex Task 8/heart.csv')

# %%
heart_data.head(10)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
# 5   57    1   0     140   192    0        1       148     0      0.4    1
# 6   56    0   1     140   294    0        0       153     0      1.3    1
# 7   44    1   1     120   263    0        1       173     0      0.0    2
# 8   52    1   2     172   199    1        1       162     0      0.5    2
# 9   57    1   2     150   168    0        1       174     0      1.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1
# ...

# %%
heart_data.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart_data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
heart_data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trtbps        int64
# chol          int64
# fbs           int64
# restecg       int64
# thalachh      int64
# exng          int64
# oldpeak     float64
# slp           int64
# caa           int64
# thall         int64
# output        int64
# dtype: object

# %%
heart_data.select_dtypes(include=['number'])
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
heart_data.duplicated().sum()
# Out:
# 1

# %%
heart_data.drop_duplicates(inplace=True)

# %%
heart_data.duplicated().sum()
# Out:
# 0

# %%
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
heart_data.shape
# Out:
# (302, 14)

# %%
o2 = pd.read_csv('/Volumes/RAJ SANKAR/Regex Task 8/o2Saturation.csv')
o2.head(10)
# Out:
#    98.6
# 0  98.6
# 1  98.6
# 2  98.6
# 3  98.1
# 4  97.5
# 5  97.5
# 6  97.5
# 7  97.5
# 8  97.5
# 9  97.5

# %%
o2.describe()
# Out:
#               98.6
# count  3585.000000
# mean     98.239275
# std       0.726336
# min      96.500000
# 25%      97.600000
# 50%      98.600000
# 75%      98.600000
# max      99.600000

# %%
o2.isnull().sum()
# Out:
# 98.6    0
# dtype: int64

# %% [markdown]
# # EDA

# %%
#plt.rcParams['figure.figsize']=(20,10)
plt.figure(figsize = (20,10))
sns.countplot(heart_data['age'],data=heart_data,palette='cubehelix')
plt.xlabel('Age', size=18)
plt.ylabel('Count',size=18)
plt.title('Age Distribution', size=25)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Age Distribution')

# %%
#1- men 0-women
heart_data.sex.value_counts()
# Out:
# 1    206
# 0     96
# Name: sex, dtype: int64

# %%
#1- men 0-women - percentage
heart_data.sex.value_counts(normalize= True)
# Out:
# 1    0.682119
# 0    0.317881
# Name: sex, dtype: float64

# %%
#plt.rcParams['figure.figsize']=(8,8)
plt.figure(figsize = (8,8))
sns.countplot(heart_data.sex,data = heart_data,palette='rocket')
plt.xlabel('Sex', size=18)
plt.ylabel('Count',size=18)
plt.title('Sex Distribution', size=20)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Sex Distribution')

# %%
# Age based on sex

fig = sns.FacetGrid(heart_data, palette = 'mako', hue = 'sex', aspect = 5)
fig.map(sns.kdeplot, 'age', shade = True, palette = 'mako')
fig.add_legend()
plt.show()

# %%
#plt.rcParams['figure.figsize']=(8,8)
plt.figure(figsize = (8,8))
sns.countplot(heart_data['cp'],palette='twilight')
plt.xlabel('Chest Pain Type', size=18)
plt.ylabel('Count',size=18)
plt.title('Type of chest pain Distribution', size=20)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Type of chest pain Distribution')

# %%
# trtbps: resting blood pressure (in mm Hg)
#plt.rcParams['figure.figsize']=(20,10)
plt.figure(figsize = (20,10))
plt.hist(heart_data['trtbps'], color='pink', bins=(80,100,110,120,130,140,150,160,190))
plt.xlabel('trtbps', size=18)
plt.ylabel('Count',size=18)
plt.title('trtbps Distribution', size=20)
# Out:
# Text(0.5, 1.0, 'trtbps Distribution')

# %%
# chol : cholestoral in mg/dl fetched via BMI sensor
#plt.rcParams['figure.figsize']=(20,10)
plt.figure(figsize = (20,10))
plt.hist(heart_data['chol'], color='yellow')
plt.xlabel('Cholestoral level', size=18)
plt.ylabel('Count',size=18)
plt.title('cholestoral Distribution', size=20)
# Out:
# Text(0.5, 1.0, 'cholestoral Distribution')

# %%
# fbs : (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#plt.rcParams['figure.figsize']=(8,8)
plt.figure(figsize = (8,8))
sns.countplot(heart_data['fbs'],palette='magma')
plt.xlabel('fbs', size=18)
plt.ylabel('Count',size=18)
plt.title('fasting blood sugar Distribution', size=20)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'fasting blood sugar Distribution')

# %%
#rest_ecg : resting electrocardiographic results
#-Value 0: normal
#-Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
#-Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
plt.figure(figsize = (8,8))
sns.countplot(heart_data['restecg'],palette='icefire')
plt.xlabel('rest_ecg', size=18)
plt.ylabel('Count',size=18)
plt.title('rest ecg Distribution', size=20)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'rest ecg Distribution')

# %%
#thalach : maximum heart rate achieved
plt.figure(figsize = (20,10))
plt.hist(heart_data['thalachh'], color=['blue'])
plt.xlabel('Thalachh', size=18)
plt.ylabel('Count',size=18)
plt.title('Thalachh Distribution', size=20)
# Out:
# Text(0.5, 1.0, 'Thalachh Distribution')

# %%
#exng: exercise induced angina (1 = yes; 0 = no)
plt.figure(figsize = (8,8))
sns.countplot(heart_data['exng'],palette='Spectral')
plt.xlabel('exng', size=18)
plt.ylabel('Count',size=18)
plt.title('exng Distribution', size=20)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'exng Distribution')

# %%
plt.figure(figsize = (20,10))
plt.hist(heart_data['oldpeak'], color='purple')
plt.xlabel('Oldpeak', size=18)
plt.ylabel('Count',size=18)
plt.title('oldpeak Distribution', size=20)
# Out:
# Text(0.5, 1.0, 'oldpeak Distribution')

# %%
#slp: slope - the slope of the peak exercise ST segment (2 = upsloping; 1 = flat; 0 = downsloping)
plt.figure(figsize = (8,8))
sns.countplot(heart_data.slp,palette='viridis')
plt.xlabel('slope', size=18)
plt.ylabel('Count',size=18)
plt.title('Slope', size=20)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Slope')

# %%
#caa - number of major vessels (0-4) colored by flourosopy
plt.figure(figsize = (8,8))
sns.countplot(heart_data['caa'],palette='YlGn')
plt.xlabel('no of vessels', size=18)
plt.ylabel('Count',size=18)
plt.title('No of vessels', size=20)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'No of vessels')

# %%
#thall - 2 = normal; 1 = fixed defect; 3 = reversable defect
plt.figure(figsize = (8,8))
sns.countplot(heart_data['thall'],palette='coolwarm')
plt.xlabel('Thall', size=18)
plt.ylabel('Count',size=18)
plt.title('Thall distribution', size=20)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Thall distribution')

# %%
sns.violinplot(x='cp',y='trtbps',data=heart_data)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='trtbps'>

# %%
plt.figure(figsize=(20,30))

plt.subplot(5,2,1)
plt.title('Prevalence of Heart attack by Sex',fontsize=15)
sns.countplot(heart_data['output'], hue=heart_data['sex'],palette='coolwarm')

plt.subplot(5,2,2)
plt.title('Prevalence of Heart attack by Chest Pain',fontsize=15)
sns.countplot(heart_data['output'], hue=heart_data['cp'],palette='Spectral')

plt.subplot(5,2,3)
plt.title('Prevalence of Heart attack by fasting blood sugar > 120 mg/dl',fontsize=15)
sns.countplot(heart_data['output'],hue=heart_data['fbs'],palette='icefire')

plt.subplot(5,2,4)
plt.title('Prevalence of Heart attack by restecg',fontsize=15)
sns.countplot(heart_data['output'],hue = heart_data.restecg,palette='cubehelix')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(20,30))

plt.subplot(5,2,5)
plt.title('Prevalence of Heart attack by Exercise induced angina',fontsize=15)
sns.countplot(heart_data['output'],hue=heart_data['exng'])

plt.subplot(5,2,6)
plt.title('Prevalence of Heart attack by slp',fontsize=15)
sns.countplot(heart_data['output'],hue=heart_data['slp'])

plt.subplot(5,2,7)
plt.title('Prevalence of Heart attack by number of major vessels',fontsize=15)
sns.countplot(heart_data['output'],hue=heart_data['caa'])

plt.subplot(5,2,8)
plt.title('Prevalence of Heart attack by thall',fontsize=15)
sns.countplot(heart_data['output'],hue=heart_data.thall)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
# Cholesterol based on sex

fig = sns.FacetGrid(heart_data, palette = 'mako', hue = 'sex', aspect = 5)
fig.map(sns.kdeplot, 'chol', shade = True, palette = 'mako')
fig.add_legend()
plt.show()

# %%
# output reprsents whether the person had a heart-attack (output=1) or not (output=0)
data = pd.crosstab(heart_data['age'], heart_data.output)
data.div(data.sum(1).astype(float),axis=0).plot(kind='bar', figsize=(20,10), color=['blue','pink'])

plt.title('Prevalence of heart attack by age', fontsize = 20)
plt.xlabel('Age', fontsize = 15)
plt.legend()
plt.show()

# %%
#stacke bar chart
# output reprsents whether the person had a heart-attack (output=1) or not (output=0)
data = pd.crosstab(heart_data['age'], heart_data['output'])
data.div(data.sum(1).astype(float),axis=0).plot(kind='bar', stacked=True, figsize=(20,10), color=['blue','pink'])

plt.title('Prevalence of heart attack by age', fontsize = 20)
plt.xlabel('Age', fontsize = 15)
plt.legend()
plt.show()

# %%
# output reprsents whether the person had a heart-attack (output=1) or not (output=0)
# trtbps: resting blood pressure (in mm Hg)
data = pd.crosstab(heart_data['trtbps'], heart_data['output'])
data.div(data.sum(1).astype(float),axis=0).plot(kind='bar', stacked=True, figsize=(20,10), color=['yellow','red'])

plt.title('Prevalence of heart attack by resting blood pressure', fontsize = 20)
plt.xlabel('trtbps', fontsize = 15)
plt.legend()
plt.show()

# %%
data = pd.crosstab(heart_data['chol'], heart_data['output'])
data.div(data.sum(1).astype(float),axis=0).plot(kind='hist', stacked=True, figsize=(20,10), color=['blue','pink'])

plt.title('Prevalence of heart attack by cholestrol', fontsize = 20)
plt.xlabel('cholestrol', fontsize = 15)
plt.legend()
plt.show()

# %%
#thalach : maximum heart rate achieved
data = pd.crosstab(heart_data['thalachh'], heart_data['output'])
data.div(data.sum(1).astype(float),axis=0).plot(kind='bar', stacked=True, figsize=(20,10), color=['yellow','red'])

plt.title('Prevalence of heart attack by maximum heart rate achieved', fontsize = 20)
plt.xlabel('thalachh', fontsize = 15)
plt.legend()
plt.show()

# %%
data = pd.crosstab(heart_data['oldpeak'], heart_data['output'])
data.div(data.sum(1).astype(float),axis=0).plot(kind='bar', stacked=True, figsize=(20,10), color=['green','black'])

plt.title('Prevalence of heart attack by oldpeak', fontsize = 20)
plt.xlabel('thalachh', fontsize = 15)
plt.legend()
plt.show()

# %%
columns = ['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh', 'caa', 'thall', 'output']
sns.pairplot(heart_data[columns], height = 3.5)

# %%
corr = heart_data.corr()
f, ax = plt.subplots(figsize=(12, 10))
cmap = sns.diverging_palette(h_neg=10, h_pos=240, as_cmap = True)
ax = sns.heatmap(corr, center=0, cmap=cmap, linewidths=1, fmt=".2f")

# %%
#convert the given matrix into a one-dimensional Series of values.

correlation_mat = corr.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# age     age        1.000000
#         sex       -0.101342
#         cp        -0.387593
#         trtbps     0.520573
#         chol       0.372805
#                      ...
# output  oldpeak   -0.796522
#         slp        0.704578
#         caa       -0.762386
#         thall     -0.691142
#         output     1.000000
# Length: 196, dtype: float64

# %%
#sort these values
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# oldpeak  slp       -0.916673
# slp      oldpeak   -0.916673
# exng     output    -0.810462
# output   exng      -0.810462
# oldpeak  output    -0.796522
#                       ...
# trtbps   trtbps     1.000000
# cp       cp         1.000000
# sex      sex        1.000000
# thall    thall      1.000000
# output   output     1.000000
# Length: 196, dtype: float64

# %%
#negative correlation pairs
negative_pairs = sorted_pairs[sorted_pairs < 0]

print(negative_pairs)
# Out:
# oldpeak  slp       -0.916673
# slp      oldpeak   -0.916673
# exng     output    -0.810462
# output   exng      -0.810462
# oldpeak  output    -0.796522
#                       ...
# output   fbs       -0.114174
# sex      age       -0.101342
# age      sex       -0.101342
# chol     fbs       -0.035572
# fbs      chol      -0.035572
# Length: 98, dtype: float64

# %%
#strong correlation
strong_pairs = sorted_pairs[sorted_pairs > 0.5]

print(strong_pairs)
# Out:
# thall     oldpeak     0.501260
# oldpeak   thall       0.501260
#           age         0.519749
# age       oldpeak     0.519749
#           trtbps      0.520573
# trtbps    age         0.520573
# exng      thall       0.530666
# thall     exng        0.530666
# oldpeak   caa         0.561557
# caa       oldpeak     0.561557
#           age         0.589550
# age       caa         0.589550
# cp        thalachh    0.634565
# thalachh  cp          0.634565
# exng      oldpeak     0.662843
# oldpeak   exng        0.662843
# output    slp         0.704578
# slp       output      0.704578
#           thalachh    0.737723
# thalachh  slp         0.737723
# output    cp          0.770553
# cp        output      0.770553
# thalachh  output      0.794094
# output    thalachh    0.794094
# age       age         1.000000
# caa       caa         1.000000
# slp       slp         1.000000
# oldpeak   oldpeak     1.000000
# exng      exng        1.000000
# thalachh  thalachh    1.000000
# ...

# %% [markdown]
# # Classification

# %%
#extract dependent features
X = heart_data.drop(['output'],axis =1).values
Y = heart_data['output'].values

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X, Y, test_size = 0.30,random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[33,  9],
#        [ 5, 44]])

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_test,y_pred)
print('Accuracy is: ', acc)
# Out:
# Accuracy is:  0.8461538461538461

# %%
from sklearn.metrics import precision_score
precision_score(y_test,y_pred)
# Out:
# 0.8301886792452831

# %%
from sklearn.metrics import recall_score
recall_score(y_test,y_pred)
# Out:
# 0.8979591836734694

# %%
from sklearn.metrics import f1_score
f1_score(y_test,y_pred)
# Out:
# 0.8627450980392157

# %%
from sklearn.naive_bayes import GaussianNB
classifier2 = GaussianNB()
classifier2.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred1 = classifier2.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm1 = confusion_matrix(y_test,y_pred1)
cm1
# Out:
# array([[35,  7],
#        [ 6, 43]])

# %%
from sklearn.metrics import accuracy_score
acc1 = accuracy_score(y_test,y_pred1)
print('Accuracy is: ', acc1)
# Out:
# Accuracy is:  0.8571428571428571

# %%
from sklearn.metrics import precision_score
precision_score(y_test,y_pred1)
# Out:
# 0.86

# %%
from sklearn.metrics import recall_score
recall_score(y_test,y_pred1)
# Out:
# 0.8775510204081632

# %%
from sklearn.metrics import f1_score
f1_score(y_test,y_pred1)
# Out:
# 0.8686868686868686

# %%
from sklearn.svm import SVC
classifier3 = SVC()
classifier3.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred2 = classifier3.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm2 = confusion_matrix(y_test,y_pred2)
cm2
# Out:
# array([[31, 11],
#        [ 7, 42]])

# %%
from sklearn.metrics import accuracy_score
acc2 = accuracy_score(y_test,y_pred2)
print("Accuracy is : ",acc2)
# Out:
# Accuracy is :  0.8021978021978022

# %%
from sklearn.metrics import precision_score
precision_score(y_test,y_pred2)
# Out:
# 0.7924528301886793

# %%
from sklearn.metrics import recall_score
recall_score(y_test,y_pred2)
# Out:
# 0.8571428571428571

# %%
from sklearn.metrics import f1_score
f1_score(y_test,y_pred2)
# Out:
# 0.8235294117647058
